# %% [markdown]
# # Taller de programación 2
# **Ing. Lic. Manuel Alejandro Quintana**
#
# (manquintana@uade.edu.ar)
#
# ![The.Matrix.glmatrix.2.png](data:image/png;base64,...)

# %% [markdown]
# # ¿A qué me dedico?
#
# ---
#
#
# **1. Consultor en el Banco Interamericano de Desarrollo.**
#
# Un poco de lo que hago:
# - Gestión de datos:
#   - Análisis y limpieza de datos.
#   - Consumo de APIs y web scraping.
#   - Gestión de bases de datos.
#   - Desarrollo de dashboards para una plataforma de datos de comercio   internacional próxima a lanzarse.
#   - Reporting de uso de comunidades en la red social del BID (Connectamericas).
#
# - Infraestructura cloud: Administración de servidores y servicios AWS (IaaS).
#
# **2. Subdirector de Infraestructura en el Congreso de la Nación.**
#
# Un poco de lo que hago:
#
# - Administración de infraestructura física: Gestión de activos, servidores físicos, cableado y redes.
# - Administración de infraestructura lógica: Active Directory, telefonía VoIP, sistemas de gestión integral, bases de datos, backups.
# - Gestión de seguridad.
#
#
# ---

# %% [markdown]
# # Repaso de taller de programación 1
#
# ¿Recuerdan estos conceptos?
# - Pseudocódigo
# - Algoritmo
# - Programa
# - Instancia
# - Tipos de datos
# - Variables
# - Estructuras condicionales
# - Estructuras iterativas
# - Estructuras de datos
#
# ¿Que otros conceptos conocen?

# %% [markdown]
# #Pseudocódigo
#
# Son pasos descriptos en un lenguaje lógico para poder realizar una acción.
#
# Ej: Una persona quiere beber una cerveza.
#
# - Agarrar un vaso
# - Agarrar una cerveza
# - Si se tiene un destapador entonces:
#   - Agarrar el destapador
# - Sino:
#   - Comprar un destapador
#   - Agarrar el destapador
# - Abrir la cerveza
# - Servirla en el vaso
# - Beber la cerveza del vaso

# %% [markdown]
# # Algoritmo
#
# Son pasos descriptos en un lenguaje lógico para poder realizar una acción. En nuestro caso tendrán el mismo nivel de detalle que un programa en python y respeta una sintaxis específica.
#
# Ej: Se ingresa la edad de una persona y se quiere indicar si es mayor o menor de edad.
#
# Mostrar("Ingrese su edad")
#
# Ingresar(edad)
#
# Si (edad >= 18) Entonces
#
# >Mostrar("La persona es mayor de edad")
#
# Sino
#
# > Mostrar ("La persona es menor de edad")
#
# FinSi

# %% [markdown]
# # Programa
#
# Es la construcción de un algoritmo pero implementado en algún lenguaje de programación.
#
# Ej: Se ingresa la edad de una persona y se quiere indicar si es mayor o menor de edad.

# %%
edad = int(input('Ingrese su edad: '))
if (edad >= 18): #T o F
  print('La persona es mayor de edad')
else:
  print('La persona es menor de edad')
# Out:
# Ingrese su edad: 14
# La persona es menor de edad

# %% [markdown]
# # Instancia
#
# Un paso después. Es cada ejecución que se haga de un programa.

# %% [markdown]
# # Tipos de datos
#
# Es la naturaleza de los datos. Cada tipo de dato tiene características particulares y comportamientos particulares.
#
# Ejemplos: Cadena de caracteres, números enteros, números decimales, booleanos (True/False), etc.

# %%
# En este caso como se trata de numeros, el operador <+> suma
numero1 = 1
numero2 = 3
print(numero1+numero2)
# Out:
# 4

# %%
# En este caso como se trata de numeros, el operador <+> concatena
palabra1 = "hola"
palabra2 = "chau"
print(palabra1+palabra2)
# Out:
# holachau

# %% [markdown]
# # Variables
#
# Son espacios en memoria que almacenan datos.
# Como vimos antes, los datos tienen un tipo de dato asociado.

# %% [markdown]
# # Python
#
# Python es un lenguaje de programación no fuertemente tipado.
# Es tipado porque maneja tipos de datos y según el tipo es el comportamiento que tendrán. Pero uno puede no definir un tipo de dato y python lo va a inferir.

# %% [markdown]
# # Estructuras condicionales
#
# Algoritmo:
#
# Si <'condicion'> Entonces
#  > Hacer esto
#
# Sino
#  > Hacer esto otro
#
# FinSi
#
# ---
# Python:
#
# if <'condicion'>:
# >Hacer esto
#
# else:
# >Hacer esto otro

# %% [markdown]
# #Estructuras iterativas
#
# # Mientras (while)
#
# **Algoritmo:**
#
# Mientras <'condicion'> Entonces
# > Hacer esto
#
# > Actualizar el valor de la variable de control
#
# FinMientras

# %%
# Ej: Se quieren ingresar numeros enteros, hasta que se ingrese un numero negativo
# y muestre la cantidad de numeros ingresados (sin contar el último)

contador = 0 # contador

numero = int(input('Ingrese un numero entero (Ingrese un numero negativo para terminar): '))
while (numero > 0): # While tiene una condicion que se rige por una variable de control: numero
  contador = contador + 1
  numero = int(input('Ingrese un numero entero (Ingrese un numero negativo para terminar): ')) #Actualizo la variable de control

print(f'La cantidad de numeros ingresada es: {contador}')
# Out:
# Ingrese un numero entero (Ingrese un numero negativo para terminar): 5
# Ingrese un numero entero (Ingrese un numero negativo para terminar): 10
# Ingrese un numero entero (Ingrese un numero negativo para terminar): -8
# La cantidad de numeros ingresada es: 2

# %%
'''
El operador f
'''
nombre = 'Manuel' # Variable de tipo string
nombre_completo = f'{nombre} Quintana' # Variable de tipo string
# El operador f indica que lo que aparezca de un string y este entre llaves {} es una variable
print(nombre_completo)
# Out:
# Manuel Quintana

# %% [markdown]
# # Para (for)
#
# Para <'variable de control'> Desde <'inicio'> hasta <'fin'> Hacer
#
#   ...
#
# FinPara
#
#
# Ej: Se quiere mostrar por pantalla los números enteros entre 1 y 5
#
# Para i Desde 1 Hasta 5 Hacer
#
# > Mostrar (i)
#
# FinPara

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Ej: Se quiere mostrar por pantalla la tabla de multiplicar del 4 entre 1 y 10
'''
4x1 = 4
4x2 = 8
4x3 = 12
4x4 = 16
...
4x10 = 40
'''
for i in range(1, 11):
  print(f'4x{i} = {4*i}')
# Out:
# 4x1 = 4
# 4x2 = 8
# 4x3 = 12
# 4x4 = 16
# 4x5 = 20
# 4x6 = 24
# 4x7 = 28
# 4x8 = 32
# 4x9 = 36
# 4x10 = 40

# %% [markdown]
# # Estructura de datos

# %% [markdown]
# Son implementaciones que nos facilitan la tarea a la hora de programar

# %% [markdown]
# *   Listas
# *   Diccionarios
# *   Json

# %%
'''
Listas

En lugar de tener por ejemplo 5 variables:
numero1 = 1
numero2 = 1
numero3 = 1412421
numero4 = 5
numero5 = 13
print(numero1)
print(numero2)
print(numero3)
print(numero4)
print(numero5)

podemos trabajar con una sola lista que tenga 5 numeros
'''
lista = [1,2,4,542,25]
print('Muestro toda la estructura de la lista:')
print(lista)

# Una lista en python es un objeto iterable
print('Forma Pythonic: Muestro los elementos de la lista iterando 1 a 1:')
for i in lista:
  print(i)

print('Forma clásica de acceder a los elementos de una lista')
for i in range(0,5):
  print(lista[i])
# Out:
# Muestro toda la estructura de la lista:
# [1, 2, 4, 542, 25]
# Forma Pythonic: Muestro los elementos de la lista iterando 1 a 1:
# 1
# 2
# 4
# 542
# 25
# Forma clásica de acceder a los elementos de una lista
# 1
# 2
# 4
# 542
# 25

# %% [markdown]
# # ¿Qué otros conceptos conocen?
#
# Conceptos de data science:
# - Big data
# - Web scraping (webscraper)
# - Estadística y proba
# - Google Analytics (reportes)
# - Excel
# - CSV
# - Datastudio
# - Bases de datos (introducción)
# - Análisis de audiencias, dimensiones y métricas
#
#
# Sugerencias:
# - Falta ver aplicaciones reales (implementaciones).
# - Trabajar con CSV (problemas de formato y de codificación)
# - Visualizaciones y Dashboards
# - API
# - Bases de datos relacionales (SQL)
# - Bases de datos no relacionales (NOSQL, por arriba)
# - Web scraping
# - Funciones
# - Modularizacion

# %% [markdown]
# Ejercicio grupal:
#
# Importar el dataset (está compartido en git) en Google colab.
#
# Mostrar:
#
# ¿Cuantas películas se lanzaron en 2019?
# ¿Cuantas películas se lanzaron entre 2017 y 2018?
# ¿Qué cantidad de películas hay publicadas?
# ¿Cuántos shows de televisión hay publicados?
# Plus:
#
# Un gráfico de barras con la cantidad de películas lanzadas por año
# Gráficos con países de origen

# %%
import pandas as pd
ruta = "/content/clase_5 - netflix_titles.csv"
df = pd.read_csv(ruta)

# %%
df
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %% [markdown]
# Películas lanzadas:

# %%
print(df.columns) #Muestra los nombres de las columnas
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
pelis_2019= df[df['release_year']==2019]
pelis_2019= pelis_2019 [pelis_2019["type"]=="Movie"]

# %%
pelis_2019
# Out:
#      show_id  ...                                        description
# 6         s7  ...  After an awful accident, a couple admitted to ...
# 8         s9  ...  When a doctor goes missing, his psychiatrist w...
# 14       s15  ...  Stranded when the Earth is suddenly destroyed ...
# 18       s19  ...  On India's Independence Day, a zany mishap in ...
# 28       s29  ...  Through her diary, Anne Frank's story is retol...
# ...      ...  ...                                                ...
# 7654   s7655  ...  When a major drug deal goes sour, the queen of...
# 7658   s7659  ...  For the 50th anniversary of the legendary Wood...
# 7739   s7740  ...  Bumbling through politics, a billionaire busin...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [582 rows x 12 columns]

# %%
print(len(pelis_2019))
# Out:
# 582

# %% [markdown]
# ¿Cuantas películas se lanzaron entre 2017 y 2018?

# %%
pelis_2017_2021= df[df['release_year']>=2017]
pelis_2017_2018= pelis_2017_2021[pelis_2017_2021['release_year']<=2018]
pelis_2017_2018= pelis_2017_2018[pelis_2017_2018['type']=="Movie"]
pelis_2017_2018
# Out:
#      show_id  ...                                        description
# 10       s11  ...  A farmer pens a confession admitting to his wi...
# 13       s14  ...  This intimate documentary follows rock star Ar...
# 17       s18  ...  After devastating terror attacks in Norway, a ...
# 19       s20  ...  Mixing old footage with interviews, this is th...
# 20       s21  ...  After accidentally connecting over the Interne...
# ...      ...  ...                                                ...
# 7751   s7752  ...  Competing con artists attempt to creatively an...
# 7764   s7765  ...  Through his relationships with two wildly diff...
# 7765   s7766  ...  After his father passes, the heir to a retail ...
# 7771   s7772  ...  Born without legs and stuck in foster care for...
# 7780   s7781  ...  A drug dealer starts having doubts about his t...
#
# [1478 rows x 12 columns]

# %%
print(len(pelis_2017_2018))
# Out:
# 1478

# %% [markdown]
# ¿que cantidad de películas hay publicadas?

# %%
movies= df[df["type"]=="Movie"]

# %%
movies
# Out:
#      show_id  ...                                        description
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# 6         s7  ...  After an awful accident, a couple admitted to ...
# ...      ...  ...                                                ...
# 7781   s7782  ...  Dragged from civilian life, a former superhero...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [5377 rows x 12 columns]

# %%
print(len(movies))
# Out:
# 5377

# %% [markdown]
# ¿cuantos shows de televisión hay publicados?

# %%
tvshows= df[df['type']=="TV Show"]

# %%
tvshows
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 5         s6  ...  A genetics professor experiments with a treatm...
# 11       s12  ...  In this dark alt-history thriller, a naïve law...
# 12       s13  ...  Archival video and new interviews examine Mexi...
# 16       s17  ...  As a psychology professor faces Alzheimer's, h...
# ...      ...  ...                                                ...
# 7767   s7768  ...  Strong-willed, middle-class Kashaf and carefre...
# 7775   s7776  ...  A quest for freedom and legendary treasure beg...
# 7777   s7778  ...  While living alone in a spooky town, a young g...
# 7779   s7780  ...  An assortment of talent takes the stage for a ...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
#
# [2410 rows x 12 columns]

# %%
print(len(tvshows))
# Out:
# 2410
